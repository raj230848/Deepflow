# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 1, 3)
y = np.linspace(0, 1, 3)
xv, yv = np.meshgrid(x, y)
z = xv-yv
xv,yv,z
# Out:
# (array([[0. , 0.5, 1. ],
#         [0. , 0.5, 1. ],
#         [0. , 0.5, 1. ]]),
#  array([[0. , 0. , 0. ],
#         [0.5, 0.5, 0.5],
#         [1. , 1. , 1. ]]),
#  array([[ 0. ,  0.5,  1. ],
#         [-0.5,  0. ,  0.5],
#         [-1. , -0.5,  0. ]]))

# %%
plt.contourf(xv, yv,z,levels=1)
plt.colorbar();
