# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("abdullah0a/student-dropout-analysis-and-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\KARAN PRATAP LOHIYA\.cache\kagglehub\datasets\abdullah0a\student-dropout-analysis-and-prediction-dataset\versions\1

# %%
import os
import  numpy as  np
import  pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import  seaborn as sns

# %%
os.chdir(path)
os.listdir()
# Out:
# ['student dropout.csv']

# %%
data=pd.read_csv('student dropout.csv')
data
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 0       GP      F   18       U         GT3               A                 4
# 1       GP      F   17       U         GT3               T                 1
# 2       GP      F   15       U         LE3               T                 1
# 3       GP      F   15       U         GT3               T                 4
# 4       GP      F   16       U         GT3               T                 3
# ..     ...    ...  ...     ...         ...             ...               ...
# 644     MS      F   19       R         GT3               T                 2
# 645     MS      F   18       U         LE3               T                 3
# 646     MS      F   18       U         GT3               T                 1
# 647     MS      M   17       U         LE3               T                 3
# 648     MS      M   18       R         LE3               T                 3
#
# ...

# %%
data.isnull().sum()
# Out:
# School                         0
# Gender                         0
# Age                            0
# Address                        0
# Family_Size                    0
# Parental_Status                0
# Mother_Education               0
# Father_Education               0
# Mother_Job                     0
# Father_Job                     0
# Reason_for_Choosing_School     0
# Guardian                       0
# Travel_Time                    0
# Study_Time                     0
# Number_of_Failures             0
# School_Support                 0
# Family_Support                 0
# Extra_Paid_Class               0
# Extra_Curricular_Activities    0
# Attended_Nursery               0
# Wants_Higher_Education         0
# Internet_Access                0
# In_Relationship                0
# Family_Relationship            0
# Free_Time                      0
# Going_Out                      0
# Weekend_Alcohol_Consumption    0
# Weekday_Alcohol_Consumption    0
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#               Age  Mother_Education  Father_Education  Travel_Time  \
# count  649.000000        649.000000        649.000000   649.000000
# mean    16.744222          2.514638          2.306626     1.568567
# std      1.218138          1.134552          1.099931     0.748660
# min     15.000000          0.000000          0.000000     1.000000
# 25%     16.000000          2.000000          1.000000     1.000000
# 50%     17.000000          2.000000          2.000000     1.000000
# 75%     18.000000          4.000000          3.000000     2.000000
# max     22.000000          4.000000          4.000000     4.000000
#
#        Study_Time  Number_of_Failures  Family_Relationship   Free_Time  \
# count  649.000000          649.000000           649.000000  649.000000
# mean     1.930663            0.221880             3.930663    3.180277
# std      0.829510            0.593235             0.955717    1.051093
# min      1.000000            0.000000             1.000000    1.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   School                       649 non-null    object
#  1   Gender                       649 non-null    object
#  2   Age                          649 non-null    int64
#  3   Address                      649 non-null    object
#  4   Family_Size                  649 non-null    object
#  5   Parental_Status              649 non-null    object
#  6   Mother_Education             649 non-null    int64
#  7   Father_Education             649 non-null    int64
#  8   Mother_Job                   649 non-null    object
#  9   Father_Job                   649 non-null    object
#  10  Reason_for_Choosing_School   649 non-null    object
#  11  Guardian                     649 non-null    object
#  12  Travel_Time                  649 non-null    int64
# ...

# %%
data.sample(10)
# Out:
#     School Gender  Age Address Family_Size Parental_Status  Mother_Education  \
# 293     GP      F   18       U         LE3               T                 1
# 345     GP      F   18       U         LE3               A                 4
# 244     GP      F   17       U         LE3               T                 4
# 346     GP      M   17       U         LE3               T                 4
# 306     GP      M   18       R         LE3               A                 3
# 371     GP      F   18       U         GT3               T                 2
# 73      GP      M   16       U         GT3               T                 3
# 411     GP      M   17       U         LE3               A                 4
# 157     GP      F   15       U         LE3               A                 2
# 423     MS      F   16       U         GT3               T                 1
#
#      Father_Education Mother_Job Father_Job  ... Free_Time Going_Out  \
# ...

# %% [markdown]
# # Exploratory analysis

# %%
columns=data.keys()
columns
# Out:
# Index(['School', 'Gender', 'Age', 'Address', 'Family_Size', 'Parental_Status',
#        'Mother_Education', 'Father_Education', 'Mother_Job', 'Father_Job',
#        'Reason_for_Choosing_School', 'Guardian', 'Travel_Time', 'Study_Time',
#        'Number_of_Failures', 'School_Support', 'Family_Support',
#        'Extra_Paid_Class', 'Extra_Curricular_Activities', 'Attended_Nursery',
#        'Wants_Higher_Education', 'Internet_Access', 'In_Relationship',
#        'Family_Relationship', 'Free_Time', 'Going_Out',
#        'Weekend_Alcohol_Consumption', 'Weekday_Alcohol_Consumption',
#        'Health_Status', 'Number_of_Absences', 'Grade_1', 'Grade_2',
#        'Final_Grade', 'Dropped_Out'],
#       dtype='object')

# %%
sns.countplot(data,x=data['Gender'],hue=data[ 'Dropped_Out'])
plt.show()

# %%
print(data['School'].unique())
sns.countplot(data,x=data['School'],hue=data[ 'Dropped_Out'])
plt.show()
# Out:
# ['GP' 'MS']

# %%
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.distplot(x=data['Age'],ax=ax[0],kde=True)
ax[0].set_title("Distribution of Age")
ax[0].set_xlabel("Age")

sns.boxplot(data,x=data['Age'],ax=ax[1])
ax[1].set_title("Boxplot of age")
ax[1].set_xlabel("Age")
plt.show()
# Out:
# C:\Users\KARAN PRATAP LOHIYA\AppData\Local\Temp\ipykernel_15684\1055137014.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['Age'],ax=ax[0],kde=True)

# %%
fig,ax=plt.subplots(1,2,figsize=(12,5))
sns.countplot(data,x=data['Mother_Job'],hue=data[ 'Dropped_Out'],ax=ax[0])
ax[0].set_xlabel("JOB")
ax[0].set_title("Father's job")
sns.countplot(data,x=data['Mother_Job'],hue=data[ 'Dropped_Out'],ax=ax[1])
ax[1].set_xlabel("JOB")
ax[1].set_title("Mother's job")
plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(12,5))
sns.histplot(data['Father_Education'],ax=axes[0])
axes[0].set_title("Father's education ")

axes[1].hist(data['Mother_Education'])
axes[1].set_title("Mother's education")
plt.show()
# print(data['Father_Education'].unique())
# plt.hist(data['Father_Education'])
# plt.show()

# %%
print(data['Wants_Higher_Education'].unique())
sns.countplot(data['Wants_Higher_Education'])
plt.show()
# Out:
# ['yes' 'no']

# %%
fig,axes=plt.subplots(1,2,figsize=(12,5))
sns.countplot(x=data['Father_Education'],hue=data[ 'Dropped_Out'],ax=axes[0])
axes[0].set_title('Father education')

sns.countplot(x=data['Mother_Education'],hue=data[ 'Dropped_Out'],ax=axes[1])
axes[1].set_title('Mothers education')
plt.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(2,2,figsize=(12,8))
sns.countplot(x=data['Weekday_Alcohol_Consumption'],hue=data['Dropped_Out'],ax=axes[0,0])
axes[0,0].set_title('week day alcohol consumption')

sns.countplot(x=data['Weekend_Alcohol_Consumption'],hue=data['Dropped_Out'],ax=axes[0,1])
axes[0,1].set_title(('weekend alcohol consumption'))

sns.histplot(x=data['Weekday_Alcohol_Consumption'],hue=data['Dropped_Out'],ax=axes[1,0])
axes[1,0].set_title('week day alcohol consumption')

sns.histplot(x=data['Weekend_Alcohol_Consumption'],hue=data['Dropped_Out'],ax=axes[1,1])
axes[1,1].set_title('weekend alcohol consumption')

plt.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(4,2,figsize=(16,12))
sns.countplot(x=data[ 'Extra_Paid_Class'],hue=data['Dropped_Out'],ax=axes[0,0])
axes[0,0].set_title( 'Participation in extra paid classes ')

sns.countplot(x=data['Extra_Curricular_Activities'],hue=data['Dropped_Out'],ax=axes[0,1])
axes[0,1].set_title('Involvement in extracurricular activities')

sns.countplot(x=data['Health_Status'],hue=data['Dropped_Out'],ax=axes[1,0])
axes[1,0].set_title(' Health rating of the student (scale 1 to 5)')

sns.countplot(x=data['Number_of_Absences'],hue=data['Dropped_Out'],ax=axes[1,1])
axes[1,1].set_title('Total number of absences from school')

sns.countplot(x=data[ 'Free_Time'],hue=data['Dropped_Out'],ax=axes[2,0])
axes[2,0].set_title(' Amount of free time after school (scale 1 to 5)')

sns.countplot(x=data['Internet_Access'],hue=data['Dropped_Out'],ax=axes[2,1])
axes[2,1].set_title('Availability of internet at home')

sns.countplot(x=data['Going_Out'],hue=data['Dropped_Out'],ax=axes[3,0])
axes[3,0].set_title('Frequency of going out with friends (scale 1 to 5')

sns.countplot(x=data['In_Relationship'],hue=data['Dropped_Out'],ax=axes[3,1])
axes[3,1].set_title('Romantic relationship status ')

plt.tight_layout()
plt.show()

# %%
# Generate a correlation heatmap

plt.figure(figsize=(15, 10))
sns.heatmap(data.corr(numeric_only=True), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
fig,ax=plt.subplots(1,3,figsize=(12,8))
sns.histplot(data=data,x=data['Final_Grade'],hue='Dropped_Out',kde='True',bins=20,ax=ax[0])
ax[0].set_title('Final grade')
sns.histplot(data=data,x=data['Grade_1'],hue='Dropped_Out',kde='True',bins=20,ax=ax[1])
ax[1].set_title('grade 1')

sns.histplot(data=data,x=data['Grade_2'],hue='Dropped_Out',kde='True',bins=20,ax=ax[2])
ax[2].set_title('grade 2')

plt.show()

# %% [markdown]
# # Model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_score,classification_report,recall_score,f1_score
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder,StandardScaler ,OneHotEncoder

# %%
# selecting caategorical and numerical columns
categorical_columns=data.select_dtypes(include=['object']).columns
numerical_columns=data.select_dtypes(include=[np.number]).columns

# %%
column_transformer=ColumnTransformer(
transformers=[('one hot',OneHotEncoder(),categorical_columns),
            ('Scaler',StandardScaler(),numerical_columns)],
 remainder='passthrough'

)

# %%
# splitting the  data before transformation into test and  train data

xtrain,xtest,ytrain,ytest=train_test_split(data.drop(columns=['Dropped_Out']),data['Dropped_Out'],test_size=0.2,random_state=42)

# %%
# applying column transformation(one hot encoding and standardization of numerical columns)

xtrain=column_transformer.fit_transform(xtrain)
xtest=column_transformer.transform(xtest)

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
ytrain=lb.fit_transform(ytrain)
ytest=lb.transform(ytest)

# %% [markdown]
# #  using different classification model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import  SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
lg=LogisticRegression(solver='liblinear',penalty='l1')
svc=SVC(kernel='sigmoid',gamma=1.0)
knn=KNeighborsClassifier()
nb=GaussianNB()
dt=DecisionTreeClassifier(max_depth=5)
rf=RandomForestClassifier(n_estimators=50,random_state=2)
ad=AdaBoostClassifier(n_estimators=50,random_state=2)
etc=ExtraTreesClassifier(n_estimators=50,random_state=2)
bg=BaggingClassifier(n_estimators=50,random_state=2)
gb=GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb=XGBClassifier(n_estimators=50,random_state=2)

# %%
classifier={
    'SVC':svc,
    'LR':lg,
    'Nb':nb,
    'KNN':knn,
    'DT':dt,
    'ETC':etc,
    'RF':rf,
    'AD':ad,
    'GB':gb,
    'BG':bg,
    'XGB':xgb
    
}

# %%
# fucntion for training the model and getting accuracy score,recall score,precision score

def train_model(clf,xtrain,ytrain,xtest,ytest):
    clf.fit(xtrain,ytrain)
    ypred=clf.predict(xtest)
    accuracy=accuracy_score(ytest,ypred)
    precision=precision_score(ytest,ypred)
    recall=recall_score(ytest,ypred)
    f1score=f1_score(ytest,ypred,average=None)
    
    return accuracy,precision,recall,f1score

# %%
# creating a list of accuracy score,recall score,precision score for all the models
acc_score=[]
prec_score=[]
recl_score=[]
f1_Score=[]

for name,clf in classifier.items():
    
    accuracy,precision,recall,f1score=train_model(clf,xtrain,ytrain,xtest,ytest)
    print(f'model name :',name)
    print(f'accuracy score :',accuracy)
    print(f'perecision score :',precision)
    print(f'recall score :',recall)
    print(f'f1 score :',f1score)
    
    print('----------------------------------------------------------------')
    
    acc_score.append(accuracy)
    prec_score.append(precision)
    recl_score.append(recall)
    f1_Score.append(f1score[0])
# Out:
# model name : SVC
# accuracy score : 0.8615384615384616
# perecision score : 0.3333333333333333
# recall score : 0.2
# f1 score : [0.92372881 0.25      ]
# ----------------------------------------------------------------
# model name : LR
# accuracy score : 1.0
# perecision score : 1.0
# recall score : 1.0
# f1 score : [1. 1.]
# ----------------------------------------------------------------
# model name : Nb
# accuracy score : 0.8846153846153846
# perecision score : 0.5
# recall score : 0.8
# f1 score : [0.9321267  0.61538462]
# ----------------------------------------------------------------
# model name : KNN
# accuracy score : 0.9
# perecision score : 0.625
# recall score : 0.3333333333333333
# f1 score : [0.94514768 0.43478261]
# ----------------------------------------------------------------
# model name : DT
# accuracy score : 1.0
# perecision score : 1.0
# recall score : 1.0
# f1 score : [1. 1.]
# ----------------------------------------------------------------
# ...

# %%
## creating a new dataframe containing all details of accuracy score,recall score,precision score for all model

performance_df=pd.DataFrame({'Algorithm':classifier.keys(),'Accuracy':acc_score,'Precision':prec_score,'Recall':recl_score,'F1 score drop out':f1_Score}).sort_values('F1 score drop out',ascending=False,ignore_index=True)
performance_df
# Out:
#    Algorithm  Accuracy  Precision    Recall  F1 score drop out
# 0         LR  1.000000   1.000000  1.000000           1.000000
# 1         DT  1.000000   1.000000  1.000000           1.000000
# 2         AD  1.000000   1.000000  1.000000           1.000000
# 3         GB  1.000000   1.000000  1.000000           1.000000
# 4         BG  1.000000   1.000000  1.000000           1.000000
# 5        XGB  1.000000   1.000000  1.000000           1.000000
# 6         RF  0.984615   1.000000  0.866667           0.991379
# 7        ETC  0.946154   0.900000  0.600000           0.970213
# 8        KNN  0.900000   0.625000  0.333333           0.945148
# 9         Nb  0.884615   0.500000  0.800000           0.932127
# 10       SVC  0.861538   0.333333  0.200000           0.923729

# %% [markdown]
# #  since we are working with the imbalanced dataset so we will choose that which has high F1 Score
